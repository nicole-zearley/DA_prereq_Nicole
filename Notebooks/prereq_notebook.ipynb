# %%
fruits = ["banana", "grape", "apple"]
print(fruits[:2])

#my name is Nicole and I am excited to learn new skills that will benefit my resume and prospects for new opportunities in the future. 
#I am working through a new step in my mental health journey, and am trying my best to not allow that to impact my work in this program any more than it already has. I appreciate any an all patience with  me!
# Out:
# ['banana', 'grape']
